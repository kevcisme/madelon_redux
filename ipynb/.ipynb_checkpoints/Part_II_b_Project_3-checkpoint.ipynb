# %% [markdown]
# # Two Percent
#
# For the following models, I used a dataset of 5,000 rows, and 5,000 columns. This is equivalent to 2% (one percent) of my initial dataset of 220,000 rows and 5,000 columns.

# %%
from os import chdir
chdir('/Users/mandymoody/DSI/projects/project_3')

# %matplotlib inline

from lib import *

# %%
from datetime import datetime
from IPython.display import display
from sklearn.decomposition import PCA 
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier 
from sklearn.feature_selection import SelectKBest, SelectFromModel, f_classif
from sklearn.linear_model import LogisticRegression, Lasso
from sklearn.model_selection import GridSearchCV, ShuffleSplit
from sklearn.neighbors import KNeighborsClassifier
from sklearn.pipeline import Pipeline
from scipy import stats, mean

# %%
feat5000_df = pd.read_pickle('5000feature_df.p')
target5000_df = pd.read_pickle('5000target_df.p')

# %%
X = feat5000_df.values
y = target5000_df.values

# %%
fourth_pipeline = Pipeline([
    ('pca', PCA()),
    ('skb', SelectKBest(k=40)),
    ('rf', RandomForestClassifier())
])

# %%
fourth_pipe_params = {
    'rf__n_estimators':[10,40,100],
    'rf__max_depth':[10,40,None]
}

# %%
fourth_pipeline_gs = GridSearchCV(fourth_pipeline,
                                 param_grid=fourth_pipe_params, 
                                 n_jobs=-1,
                                 cv=ShuffleSplit(random_state=42)                               
)

# %%
fourth_start_time = datetime.now()
fourth_pipeline_gs.fit(X, y.ravel())
fourth_end_time = datetime.now()

# %%
fourth_pipeline_total_time = fourth_end_time - fourth_start_time
total_minutes_5k_fourth_pipeline = (fourth_pipeline_total_time.total_seconds()) / 60
total_minutes_5k_fourth_pipeline
# Out:
# 101.83026131666666

# %%
fourth_pipeline_results = pd.DataFrame(fourth_pipeline_gs.cv_results_)
fourth_pipeline_results.T
# Out:
#                                                                     0  \
# mean_fit_time                                                 267.518
# mean_score_time                                               1.37939
# mean_test_score                                                0.5034
# mean_train_score                                             0.898689
# param_rf__max_depth                                                10
# param_rf__n_estimators                                             10
# params                  {'rf__max_depth': 10, 'rf__n_estimators': 10}
# rank_test_score                                                     4
# split0_test_score                                               0.528
# split0_train_score                                           0.917111
# split1_test_score                                               0.506
# split1_train_score                                           0.905111
# split2_test_score                                               0.512
# split2_train_score                                           0.897556
# split3_test_score                                               0.494
# split3_train_score                                           0.890444
# split4_test_score                                               0.486
# split4_train_score                                           0.896667
# split5_test_score                                               0.492
# split5_train_score                                           0.913778
# split6_test_score                                               0.518
# split6_train_score                                           0.891556
# split7_test_score                                               0.492
# split7_train_score                                           0.894889
# split8_test_score                                               0.526
# split8_train_score                                           0.887333
# split9_test_score                                                0.48
# split9_train_score                                           0.892444
# std_fit_time                                                  3.46831
# std_score_time                                               0.361035
# std_test_score                                              0.0161505
# std_train_score                                            0.00956509
#
#                                                                     1  \
# mean_fit_time                                                 264.802
# mean_score_time                                                1.4811
# mean_test_score                                                 0.494
# mean_train_score                                             0.979044
# param_rf__max_depth                                                10
# param_rf__n_estimators                                             40
# params                  {'rf__max_depth': 10, 'rf__n_estimators': 40}
# rank_test_score                                                     8
# split0_test_score                                                0.54
# split0_train_score                                           0.980222
# split1_test_score                                                0.49
# split1_train_score                                           0.974889
# split2_test_score                                               0.488
# split2_train_score                                           0.984222
# split3_test_score                                               0.502
# split3_train_score                                           0.982222
# split4_test_score                                               0.478
# split4_train_score                                              0.972
# split5_test_score                                               0.526
# split5_train_score                                           0.979778
# split6_test_score                                               0.476
# split6_train_score                                           0.982444
# split7_test_score                                               0.496
# split7_train_score                                           0.980222
# split8_test_score                                               0.458
# split8_train_score                                           0.976222
# split9_test_score                                               0.486
# split9_train_score                                           0.978222
# std_fit_time                                                  2.12184
# std_score_time                                               0.343524
# std_test_score                                              0.0228035
# std_train_score                                             0.0035681
#
#                                                                      2  \
# mean_fit_time                                                  265.365
# mean_score_time                                                1.41051
# mean_test_score                                                  0.491
# mean_train_score                                              0.992311
# param_rf__max_depth                                                 10
# param_rf__n_estimators                                             100
# params                  {'rf__max_depth': 10, 'rf__n_estimators': 100}
# rank_test_score                                                      9
# split0_test_score                                                 0.48
# split0_train_score                                               0.994
# split1_test_score                                                0.508
# split1_train_score                                            0.990667
# split2_test_score                                                0.528
# split2_train_score                                            0.994222
# split3_test_score                                                0.502
# split3_train_score                                            0.994889
# split4_test_score                                                0.502
# split4_train_score                                            0.987556
# split5_test_score                                                0.494
# split5_train_score                                            0.993333
# split6_test_score                                                 0.45
# split6_train_score                                            0.994889
# split7_test_score                                                0.494
# split7_train_score                                            0.991778
# split8_test_score                                                0.482
# split8_train_score                                            0.990444
# split9_test_score                                                 0.47
# split9_train_score                                            0.991333
# std_fit_time                                                   6.34453
# std_score_time                                                0.296809
# std_test_score                                               0.0205961
# std_train_score                                             0.00225575
#
#                                                                     3  \
# mean_fit_time                                                 266.342
# mean_score_time                                               1.34076
# mean_test_score                                                0.5074
# mean_train_score                                               0.9868
# param_rf__max_depth                                                40
# param_rf__n_estimators                                             10
# params                  {'rf__max_depth': 40, 'rf__n_estimators': 10}
# rank_test_score                                                     1
# split0_test_score                                               0.506
# split0_train_score                                           0.982889
# split1_test_score                                                0.48
# split1_train_score                                           0.988889
# split2_test_score                                               0.518
# split2_train_score                                           0.988222
# split3_test_score                                               0.514
# split3_train_score                                           0.990889
# split4_test_score                                               0.514
# split4_train_score                                           0.988444
# split5_test_score                                               0.526
# split5_train_score                                           0.986222
# split6_test_score                                               0.494
# split6_train_score                                              0.986
# split7_test_score                                               0.526
# split7_train_score                                           0.985778
# split8_test_score                                               0.508
# split8_train_score                                           0.986444
# split9_test_score                                               0.488
# split9_train_score                                           0.984222
# std_fit_time                                                  2.15001
# std_score_time                                               0.282389
# std_test_score                                              0.0148337
# std_train_score                                            0.00223375
#
#                                                                     4  \
# mean_fit_time                                                 255.424
# mean_score_time                                               1.26019
# mean_test_score                                                 0.499
# mean_train_score                                                    1
# param_rf__max_depth                                                40
# param_rf__n_estimators                                             40
# params                  {'rf__max_depth': 40, 'rf__n_estimators': 40}
# rank_test_score                                                     6
# split0_test_score                                               0.512
# split0_train_score                                                  1
# split1_test_score                                               0.472
# split1_train_score                                                  1
# split2_test_score                                               0.494
# split2_train_score                                                  1
# split3_test_score                                               0.514
# split3_train_score                                                  1
# split4_test_score                                               0.512
# split4_train_score                                                  1
# split5_test_score                                                0.51
# split5_train_score                                                  1
# split6_test_score                                               0.492
# split6_train_score                                                  1
# split7_test_score                                               0.504
# split7_train_score                                                  1
# split8_test_score                                                 0.5
# split8_train_score                                                  1
# split9_test_score                                                0.48
# split9_train_score                                                  1
# std_fit_time                                                  12.7199
# std_score_time                                               0.376876
# std_test_score                                              0.0136894
# std_train_score                                                     0
#
#                                                                      5  \
# mean_fit_time                                                  247.295
# mean_score_time                                                1.34118
# mean_test_score                                                 0.5038
# mean_train_score                                                     1
# param_rf__max_depth                                                 40
# param_rf__n_estimators                                             100
# params                  {'rf__max_depth': 40, 'rf__n_estimators': 100}
# rank_test_score                                                      3
# split0_test_score                                                0.506
# split0_train_score                                                   1
# split1_test_score                                                0.502
# split1_train_score                                                   1
# split2_test_score                                                0.528
# split2_train_score                                                   1
# split3_test_score                                                0.498
# split3_train_score                                                   1
# split4_test_score                                                 0.51
# split4_train_score                                                   1
# split5_test_score                                                0.504
# split5_train_score                                                   1
# split6_test_score                                                 0.49
# split6_train_score                                                   1
# split7_test_score                                                0.494
# split7_train_score                                                   1
# split8_test_score                                                0.484
# split8_train_score                                                   1
# split9_test_score                                                0.522
# split9_train_score                                                   1
# std_fit_time                                                    1.3514
# std_score_time                                                 0.28226
# std_test_score                                               0.0129445
# std_train_score                                                      0
#
#                                                                       6  \
# mean_fit_time                                                   240.082
# mean_score_time                                                 1.38229
# mean_test_score                                                  0.5008
# mean_train_score                                               0.986089
# param_rf__max_depth                                                None
# param_rf__n_estimators                                               10
# params                  {'rf__max_depth': None, 'rf__n_estimators': 10}
# rank_test_score                                                       5
# split0_test_score                                                 0.506
# split0_train_score                                             0.985111
# split1_test_score                                                 0.496
# split1_train_score                                             0.984889
# split2_test_score                                                 0.496
# split2_train_score                                             0.987778
# split3_test_score                                                  0.52
# split3_train_score                                                0.986
# split4_test_score                                                 0.516
# split4_train_score                                             0.984444
# split5_test_score                                                 0.488
# split5_train_score                                             0.986444
# split6_test_score                                                 0.504
# split6_train_score                                             0.987778
# split7_test_score                                                 0.472
# split7_train_score                                             0.986444
# split8_test_score                                                 0.504
# split8_train_score                                             0.984222
# split9_test_score                                                 0.506
# split9_train_score                                             0.987778
# std_fit_time                                                    2.55954
# std_score_time                                                 0.135912
# std_test_score                                                0.0130905
# std_train_score                                              0.00131918
#
#                                                                       7  \
# mean_fit_time                                                   237.822
# mean_score_time                                                 1.37041
# mean_test_score                                                  0.4974
# mean_train_score                                                      1
# param_rf__max_depth                                                None
# param_rf__n_estimators                                               40
# params                  {'rf__max_depth': None, 'rf__n_estimators': 40}
# rank_test_score                                                       7
# split0_test_score                                                  0.54
# split0_train_score                                                    1
# split1_test_score                                                  0.51
# split1_train_score                                                    1
# split2_test_score                                                 0.446
# split2_train_score                                                    1
# split3_test_score                                                 0.546
# split3_train_score                                                    1
# split4_test_score                                                 0.442
# split4_train_score                                                    1
# split5_test_score                                                 0.504
# split5_train_score                                                    1
# split6_test_score                                                 0.488
# split6_train_score                                                    1
# split7_test_score                                                 0.524
# split7_train_score                                                    1
# split8_test_score                                                 0.508
# split8_train_score                                                    1
# split9_test_score                                                 0.466
# split9_train_score                                                    1
# std_fit_time                                                    1.49333
# std_score_time                                                 0.209307
# std_test_score                                                0.0346185
# std_train_score                                                       0
#
#                                                                        8
# mean_fit_time                                                    215.551
# mean_score_time                                                  1.08613
# mean_test_score                                                   0.5054
# mean_train_score                                                       1
# param_rf__max_depth                                                 None
# param_rf__n_estimators                                               100
# params                  {'rf__max_depth': None, 'rf__n_estimators': 100}
# rank_test_score                                                        2
# split0_test_score                                                  0.528
# split0_train_score                                                     1
# split1_test_score                                                  0.512
# split1_train_score                                                     1
# split2_test_score                                                  0.504
# split2_train_score                                                     1
# split3_test_score                                                  0.512
# split3_train_score                                                     1
# split4_test_score                                                  0.512
# split4_train_score                                                     1
# split5_test_score                                                  0.496
# split5_train_score                                                     1
# split6_test_score                                                    0.5
# split6_train_score                                                     1
# split7_test_score                                                  0.522
# split7_train_score                                                     1
# split8_test_score                                                   0.48
# split8_train_score                                                     1
# split9_test_score                                                  0.488
# split9_train_score                                                     1
# std_fit_time                                                     47.2661
# std_score_time                                                  0.234169
# std_test_score                                                 0.0140869
# std_train_score                                                        0

# %%
fourth_pipeline_results.to_pickle('fourth_pipeline_results5k.p')

# %%
fifth_pipeline = Pipeline([
    ('pca', PCA()),
    ('sfm', SelectFromModel(Lasso())),
    ('knc', KNeighborsClassifier()) 
])

# %%
fifth_pipe_params = {
    'knc__n_neighbors':[5,7],
    'knc__n_jobs':[-1]
}

# %%
fifth_pipeline_gs = GridSearchCV(fifth_pipeline,
                                 param_grid=fifth_pipe_params, 
                                 n_jobs=-1,
                                 cv=ShuffleSplit(random_state=42)                               
)

# %%
fifth_pipeline_start_time = datetime.now()
fifth_pipeline_gs.fit(X, y.ravel())
fifth_pipeline_end_time = datetime.now()

# %%
fifth_pipeline_total_time = fifth_pipeline_end_time - fifth_pipeline_start_time
total_minutes_5k_fifth_pipeline = (fifth_pipeline_total_time.total_seconds()) / 60
total_minutes_5k_fifth_pipeline

# %%
fifth_pipeline_results = pd.DataFrame(fifth_pipeline_gs.cv_results_)
fifth_pipeline_results.T

# %%
fifth_pipeline_results.to_pickle('fifth_pipeline_results5k.p')

# %%
sixth_pipeline = Pipeline([
    ('pca', PCA()),
    ('skb', SelectKBest(k=40)),
    ('et', ExtraTreesClassifier())
])

# %%
sixth_pipe_params = {
    'et__n_estimators':[10,40,100],
    'et__max_depth':[10,40,None]
}

# %%
sixth_pipeline_gs = GridSearchCV(sixth_pipeline,
                                 param_grid=sixth_pipe_params, 
                                 n_jobs=-1,
                                 cv=ShuffleSplit(random_state=42)                               
)

# %%
sixth_pipeline_start_time = datetime.now()
sixth_pipeline_gs.fit(X, y.ravel())
sixth_pipeline_end_time = datetime.now()

# %%
sixth_pipeline_total_time = sixth_pipeline_end_time - sixth_pipeline_start_time
total_minutes_5k_sixth_pipeline = (sixth_pipeline_total_time.total_seconds()) / 60
total_minutes_5k_sixth_pipeline
# Out:
# 99.04827135000001

# %%
sixth_pipeline_results = pd.DataFrame(sixth_pipeline_gs.cv_results_)
sixth_pipeline_results.T
# Out:
#                                                                     0  \
# mean_fit_time                                                 257.718
# mean_score_time                                               1.26871
# mean_test_score                                                0.4888
# mean_train_score                                             0.877422
# param_et__max_depth                                                10
# param_et__n_estimators                                             10
# params                  {'et__max_depth': 10, 'et__n_estimators': 10}
# rank_test_score                                                     9
# split0_test_score                                               0.504
# split0_train_score                                           0.880222
# split1_test_score                                               0.512
# split1_train_score                                           0.877778
# split2_test_score                                               0.484
# split2_train_score                                           0.875111
# split3_test_score                                               0.498
# split3_train_score                                           0.885111
# split4_test_score                                               0.468
# split4_train_score                                           0.876667
# split5_test_score                                               0.488
# split5_train_score                                              0.884
# split6_test_score                                               0.456
# split6_train_score                                           0.868667
# split7_test_score                                               0.524
# split7_train_score                                              0.874
# split8_test_score                                                0.47
# split8_train_score                                           0.881778
# split9_test_score                                               0.484
# split9_train_score                                           0.870889
# std_fit_time                                                  2.05951
# std_score_time                                               0.212608
# std_test_score                                               0.020004
# std_train_score                                            0.00516034
#
#                                                                     1  \
# mean_fit_time                                                 253.801
# mean_score_time                                               1.36062
# mean_test_score                                                0.4964
# mean_train_score                                             0.959067
# param_et__max_depth                                                10
# param_et__n_estimators                                             40
# params                  {'et__max_depth': 10, 'et__n_estimators': 40}
# rank_test_score                                                     4
# split0_test_score                                               0.508
# split0_train_score                                           0.959778
# split1_test_score                                               0.496
# split1_train_score                                           0.960889
# split2_test_score                                               0.544
# split2_train_score                                           0.958667
# split3_test_score                                               0.468
# split3_train_score                                           0.961778
# split4_test_score                                                0.49
# split4_train_score                                           0.957556
# split5_test_score                                               0.512
# split5_train_score                                           0.963111
# split6_test_score                                               0.476
# split6_train_score                                           0.956667
# split7_test_score                                               0.502
# split7_train_score                                           0.961333
# split8_test_score                                               0.482
# split8_train_score                                           0.948444
# split9_test_score                                               0.486
# split9_train_score                                           0.962444
# std_fit_time                                                 0.375786
# std_score_time                                               0.219048
# std_test_score                                              0.0206262
# std_train_score                                            0.00406345
#
#                                                                      2  \
# mean_fit_time                                                  254.295
# mean_score_time                                                1.25249
# mean_test_score                                                 0.4956
# mean_train_score                                              0.978667
# param_et__max_depth                                                 10
# param_et__n_estimators                                             100
# params                  {'et__max_depth': 10, 'et__n_estimators': 100}
# rank_test_score                                                      5
# split0_test_score                                                0.528
# split0_train_score                                                0.98
# split1_test_score                                                0.486
# split1_train_score                                            0.978667
# split2_test_score                                                0.514
# split2_train_score                                                0.98
# split3_test_score                                                0.474
# split3_train_score                                                0.98
# split4_test_score                                                0.508
# split4_train_score                                            0.977333
# split5_test_score                                                0.512
# split5_train_score                                            0.977556
# split6_test_score                                                 0.44
# split6_train_score                                            0.980222
# split7_test_score                                                 0.53
# split7_train_score                                            0.976667
# split8_test_score                                                0.482
# split8_train_score                                            0.977778
# split9_test_score                                                0.482
# split9_train_score                                            0.978444
# std_fit_time                                                   3.37861
# std_score_time                                                0.204018
# std_test_score                                               0.0264847
# std_train_score                                              0.0012492
#
#                                                                     3  \
# mean_fit_time                                                 249.405
# mean_score_time                                               1.31514
# mean_test_score                                                0.5004
# mean_train_score                                                    1
# param_et__max_depth                                                40
# param_et__n_estimators                                             10
# params                  {'et__max_depth': 40, 'et__n_estimators': 10}
# rank_test_score                                                     2
# split0_test_score                                               0.484
# split0_train_score                                                  1
# split1_test_score                                               0.484
# split1_train_score                                                  1
# split2_test_score                                               0.496
# split2_train_score                                                  1
# split3_test_score                                               0.502
# split3_train_score                                                  1
# split4_test_score                                                0.47
# split4_train_score                                                  1
# split5_test_score                                               0.506
# split5_train_score                                                  1
# split6_test_score                                               0.536
# split6_train_score                                                  1
# split7_test_score                                               0.482
# split7_train_score                                                  1
# split8_test_score                                               0.542
# split8_train_score                                                  1
# split9_test_score                                               0.502
# split9_train_score                                                  1
# std_fit_time                                                  1.81148
# std_score_time                                               0.178311
# std_test_score                                              0.0220327
# std_train_score                                                     0
#
#                                                                     4  \
# mean_fit_time                                                 237.746
# mean_score_time                                               1.08543
# mean_test_score                                                0.4926
# mean_train_score                                                    1
# param_et__max_depth                                                40
# param_et__n_estimators                                             40
# params                  {'et__max_depth': 40, 'et__n_estimators': 40}
# rank_test_score                                                     8
# split0_test_score                                               0.484
# split0_train_score                                                  1
# split1_test_score                                                0.49
# split1_train_score                                                  1
# split2_test_score                                               0.512
# split2_train_score                                                  1
# split3_test_score                                                0.49
# split3_train_score                                                  1
# split4_test_score                                               0.486
# split4_train_score                                                  1
# split5_test_score                                                0.51
# split5_train_score                                                  1
# split6_test_score                                               0.496
# split6_train_score                                                  1
# split7_test_score                                               0.492
# split7_train_score                                                  1
# split8_test_score                                               0.442
# split8_train_score                                                  1
# split9_test_score                                               0.524
# split9_train_score                                                  1
# std_fit_time                                                  3.76657
# std_score_time                                               0.230321
# std_test_score                                              0.0209007
# std_train_score                                                     0
#
#                                                                      5  \
# mean_fit_time                                                  244.388
# mean_score_time                                                1.28147
# mean_test_score                                                 0.5056
# mean_train_score                                                     1
# param_et__max_depth                                                 40
# param_et__n_estimators                                             100
# params                  {'et__max_depth': 40, 'et__n_estimators': 100}
# rank_test_score                                                      1
# split0_test_score                                                0.506
# split0_train_score                                                   1
# split1_test_score                                                 0.48
# split1_train_score                                                   1
# split2_test_score                                                0.504
# split2_train_score                                                   1
# split3_test_score                                                0.528
# split3_train_score                                                   1
# split4_test_score                                                0.524
# split4_train_score                                                   1
# split5_test_score                                                0.494
# split5_train_score                                                   1
# split6_test_score                                                 0.46
# split6_train_score                                                   1
# split7_test_score                                                0.526
# split7_train_score                                                   1
# split8_test_score                                                  0.5
# split8_train_score                                                   1
# split9_test_score                                                0.534
# split9_train_score                                                   1
# std_fit_time                                                   2.69255
# std_score_time                                                0.264461
# std_test_score                                               0.0222854
# std_train_score                                                      0
#
#                                                                       6  \
# mean_fit_time                                                   238.931
# mean_score_time                                                 1.12822
# mean_test_score                                                   0.493
# mean_train_score                                                      1
# param_et__max_depth                                                None
# param_et__n_estimators                                               10
# params                  {'et__max_depth': None, 'et__n_estimators': 10}
# rank_test_score                                                       7
# split0_test_score                                                 0.448
# split0_train_score                                                    1
# split1_test_score                                                 0.476
# split1_train_score                                                    1
# split2_test_score                                                   0.5
# split2_train_score                                                    1
# split3_test_score                                                 0.524
# split3_train_score                                                    1
# split4_test_score                                                 0.512
# split4_train_score                                                    1
# split5_test_score                                                  0.51
# split5_train_score                                                    1
# split6_test_score                                                 0.496
# split6_train_score                                                    1
# split7_test_score                                                 0.468
# split7_train_score                                                    1
# split8_test_score                                                 0.488
# split8_train_score                                                    1
# split9_test_score                                                 0.508
# split9_train_score                                                    1
# std_fit_time                                                    1.11733
# std_score_time                                                 0.233993
# std_test_score                                                0.0220409
# std_train_score                                                       0
#
#                                                                       7  \
# mean_fit_time                                                   238.948
# mean_score_time                                                 1.24182
# mean_test_score                                                  0.4932
# mean_train_score                                                      1
# param_et__max_depth                                                None
# param_et__n_estimators                                               40
# params                  {'et__max_depth': None, 'et__n_estimators': 40}
# rank_test_score                                                       6
# split0_test_score                                                 0.482
# split0_train_score                                                    1
# split1_test_score                                                 0.496
# split1_train_score                                                    1
# split2_test_score                                                 0.464
# split2_train_score                                                    1
# split3_test_score                                                 0.492
# split3_train_score                                                    1
# split4_test_score                                                   0.5
# split4_train_score                                                    1
# split5_test_score                                                 0.458
# split5_train_score                                                    1
# split6_test_score                                                  0.52
# split6_train_score                                                    1
# split7_test_score                                                  0.51
# split7_train_score                                                    1
# split8_test_score                                                 0.496
# split8_train_score                                                    1
# split9_test_score                                                 0.514
# split9_train_score                                                    1
# std_fit_time                                                    1.05131
# std_score_time                                                 0.265736
# std_test_score                                                0.0192707
# std_train_score                                                       0
#
#                                                                        8
# mean_fit_time                                                    216.154
# mean_score_time                                                  1.04191
# mean_test_score                                                   0.4978
# mean_train_score                                                       1
# param_et__max_depth                                                 None
# param_et__n_estimators                                               100
# params                  {'et__max_depth': None, 'et__n_estimators': 100}
# rank_test_score                                                        3
# split0_test_score                                                  0.464
# split0_train_score                                                     1
# split1_test_score                                                  0.516
# split1_train_score                                                     1
# split2_test_score                                                   0.51
# split2_train_score                                                     1
# split3_test_score                                                  0.536
# split3_train_score                                                     1
# split4_test_score                                                  0.508
# split4_train_score                                                     1
# split5_test_score                                                  0.508
# split5_train_score                                                     1
# split6_test_score                                                  0.458
# split6_train_score                                                     1
# split7_test_score                                                  0.478
# split7_train_score                                                     1
# split8_test_score                                                  0.496
# split8_train_score                                                     1
# split9_test_score                                                  0.504
# split9_train_score                                                     1
# std_fit_time                                                     48.3773
# std_score_time                                                  0.288156
# std_test_score                                                 0.0230382
# std_train_score                                                        0

# %%
sixth_pipeline_results.to_pickle('sixth_pipeline_results5k.p')
